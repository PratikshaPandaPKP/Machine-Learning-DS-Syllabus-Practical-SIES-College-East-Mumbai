# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Load the dataset
data = pd.read_csv('/content/PenguinsData.csv')  # Ensure the path to your dataset is correct
data.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# Clean the dataset (dropping rows with missing values)
cleaned_data = data.dropna(subset=['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)'])
cleaned_data.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5   PAL0708              6  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
# 5  Torgersen  Adult, 1 Egg Stage          N3A2               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 4                36.7               19.3                193.0         3450.0
# 5                39.3               20.6                190.0         3650.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 4  FEMALE            8.76651          -25.32426
# 5    MALE            8.66496          -25.29805
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 4                             NaN
# 5                             NaN

# %%
# Convert numeric columns to categorical bins
cleaned_data.loc[:, 'Culmen Length (mm)'] = pd.cut(cleaned_data['Culmen Length (mm)'], bins=3, labels=["short", "medium", "long"])
cleaned_data.loc[:, 'Culmen Depth (mm)'] = pd.cut(cleaned_data['Culmen Depth (mm)'], bins=3, labels=["shallow", "medium", "deep"])
cleaned_data.loc[:, 'Flipper Length (mm)'] = pd.cut(cleaned_data['Flipper Length (mm)'], bins=3, labels=["short", "medium", "long"])
cleaned_data.loc[:, 'Body Mass (g)'] = pd.cut(cleaned_data['Body Mass (g)'], bins=3, labels=["light", "medium", "heavy"])

# One-hot encode the categorical data
one_hot_data = pd.get_dummies(cleaned_data[['Species', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']])

one_hot_data
# Out:
#      Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0                                           True
# 1                                           True
# 2                                           True
# 4                                           True
# 5                                           True
# ..                                           ...
# 338                                        False
# 340                                        False
# 341                                        False
# 342                                        False
# 343                                        False
#
#      Species_Chinstrap penguin (Pygoscelis antarctica)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 4                                                False
# 5                                                False
# ..                                                 ...
# 338                                              False
# 340                                              False
# 341                                              False
# 342                                              False
# 343                                              False
#
#      Species_Gentoo penguin (Pygoscelis papua)  Culmen Length (mm)_short  \
# 0                                        False                      True
# 1                                        False                      True
# 2                                        False                      True
# 4                                        False                      True
# 5                                        False                      True
# ..                                         ...                       ...
# 338                                       True                     False
# 340                                       True                     False
# 341                                       True                     False
# 342                                       True                     False
# 343                                       True                     False
#
#      Culmen Length (mm)_medium  Culmen Length (mm)_long  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 4                        False                    False
# 5                        False                    False
# ..                         ...                      ...
# 338                       True                    False
# 340                       True                    False
# 341                       True                    False
# 342                       True                    False
# 343                       True                    False
#
#      Culmen Depth (mm)_shallow  Culmen Depth (mm)_medium  \
# 0                        False                      True
# 1                        False                      True
# 2                        False                      True
# 4                        False                     False
# 5                        False                     False
# ..                         ...                       ...
# 338                       True                     False
# 340                       True                     False
# 341                       True                     False
# 342                       True                     False
# 343                      False                      True
#
#      Culmen Depth (mm)_deep  Flipper Length (mm)_short  \
# 0                     False                       True
# 1                     False                       True
# 2                     False                      False
# 4                      True                      False
# 5                      True                       True
# ..                      ...                        ...
# 338                   False                      False
# 340                   False                      False
# 341                   False                      False
# 342                   False                      False
# 343                   False                      False
#
#      Flipper Length (mm)_medium  Flipper Length (mm)_long  \
# 0                         False                     False
# 1                         False                     False
# 2                          True                     False
# 4                          True                     False
# 5                         False                     False
# ..                          ...                       ...
# 338                       False                      True
# 340                       False                      True
# 341                       False                      True
# 342                       False                      True
# 343                       False                      True
#
#      Body Mass (g)_light  Body Mass (g)_medium  Body Mass (g)_heavy
# 0                   True                 False                False
# 1                   True                 False                False
# 2                   True                 False                False
# 4                   True                 False                False
# 5                   True                 False                False
# ..                   ...                   ...                  ...
# 338                False                  True                False
# 340                False                  True                False
# 341                False                 False                 True
# 342                False                 False                 True
# 343                False                 False                 True
#
# [342 rows x 15 columns]

# %%
# Apply the Apriori algorithm
frequent_itemsets = apriori(one_hot_data, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.441520      (Species_Adelie Penguin (Pygoscelis adeliae))
# 1   0.198830  (Species_Chinstrap penguin (Pygoscelis antarct...
# 2   0.359649        (Species_Gentoo penguin (Pygoscelis papua))
# 3   0.371345                         (Culmen Length (mm)_short)
# 4   0.500000                        (Culmen Length (mm)_medium)
# ..       ...                                                ...
# 93  0.128655  (Culmen Depth (mm)_shallow, Species_Gentoo pen...
# 94  0.178363  (Flipper Length (mm)_short, Culmen Depth (mm)_...
# 95  0.122807  (Culmen Depth (mm)_shallow, Flipper Length (mm...
# 96  0.175439  (Flipper Length (mm)_short, Culmen Depth (mm)_...
# 97  0.122807  (Flipper Length (mm)_long, Culmen Length (mm)_...
#
# [98 rows x 2 columns]

# %%
# Generate the association rules
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.6)

rules
# Out:
#                                            antecedents  \
# 0        (Species_Adelie Penguin (Pygoscelis adeliae))
# 1                           (Culmen Length (mm)_short)
# 2        (Species_Adelie Penguin (Pygoscelis adeliae))
# 3                           (Culmen Depth (mm)_medium)
# 4                             (Culmen Depth (mm)_deep)
# ..                                                 ...
# 263  (Culmen Depth (mm)_shallow, Body Mass (g)_medi...
# 264  (Culmen Depth (mm)_shallow, Species_Gentoo pen...
# 265   (Flipper Length (mm)_long, Body Mass (g)_medium)
# 266  (Species_Gentoo penguin (Pygoscelis papua), Bo...
# 267  (Culmen Depth (mm)_shallow, Body Mass (g)_medium)
#
#                                            consequents  antecedent support  \
# 0                           (Culmen Length (mm)_short)            0.441520
# 1        (Species_Adelie Penguin (Pygoscelis adeliae))            0.371345
# 2                           (Culmen Depth (mm)_medium)            0.441520
# 3        (Species_Adelie Penguin (Pygoscelis adeliae))            0.461988
# 4        (Species_Adelie Penguin (Pygoscelis adeliae))            0.236842
# ..                                                 ...                 ...
# 263  (Species_Gentoo penguin (Pygoscelis papua), Fl...            0.192982
# 264  (Flipper Length (mm)_long, Culmen Length (mm)_...            0.198830
# 265  (Culmen Depth (mm)_shallow, Species_Gentoo pen...            0.131579
# 266  (Culmen Depth (mm)_shallow, Flipper Length (mm...            0.198830
# 267  (Species_Gentoo penguin (Pygoscelis papua), Fl...            0.198830
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.371345  0.365497    0.827815  2.229233               1.0
# 1              0.441520  0.365497    0.984252  2.229233               1.0
# 2              0.461988  0.280702    0.635762  1.376142               1.0
# 3              0.441520  0.280702    0.607595  1.376142               1.0
# 4              0.441520  0.154971    0.654321  1.481972               1.0
# ..                  ...       ...         ...       ...               ...
# 263            0.283626  0.122807    0.636364  2.243674               1.0
# 264            0.230994  0.122807    0.617647  2.673864               1.0
# 265            0.266082  0.122807    0.933333  3.507692               1.0
# 266            0.190058  0.122807    0.617647  3.249774               1.0
# 267            0.228070  0.122807    0.617647  2.708145               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.201541    3.651035       0.987351  0.816993   0.726105    0.906033
# 1    0.201541   35.463450       0.877135  0.816993   0.971802    0.906033
# 2    0.076724    1.477087       0.489420  0.450704   0.322992    0.621678
# 3    0.076724    1.423222       0.508039  0.450704   0.297369    0.621678
# 4    0.050400    1.615602       0.426155  0.296089   0.381035    0.502657
# ..        ...         ...            ...       ...        ...         ...
# 263  0.068072    1.970029       0.686853  0.347107   0.492393    0.534677
# 264  0.076878    2.011246       0.781369  0.400000   0.502796    0.574646
# 265  0.087796   11.008772       0.823232  0.446809   0.909163    0.697436
# 266  0.085018    2.118309       0.864095  0.461538   0.527925    0.631900
# 267  0.077460    2.018893       0.787278  0.403846   0.504679    0.578054
#
# [268 rows x 14 columns]

# %%
# Filter rules with support > 0.3 and confidence > 0.8
filtered_rules = rules[(rules['support'] > 0.3) & (rules['confidence'] > 0.8)]

# Select only relevant columns: antecedents, support, and confidence
cleaned_output = filtered_rules[['antecedents', 'support', 'confidence']]

cleaned_output
# Out:
#                                       antecedents   support  confidence
# 0   (Species_Adelie Penguin (Pygoscelis adeliae))  0.365497    0.827815
# 1                      (Culmen Length (mm)_short)  0.365497    0.984252
# 12    (Species_Gentoo penguin (Pygoscelis papua))  0.304094    0.845528
